# %% [markdown]
# # Visualize My Caches
# Application uses Folium to map caches

# %%
# Import standard libraries
import re
import xml.etree.ElementTree as ET

# Import external libraries
import folium
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import the Geocaching data file
# You can generate and download a pocket query containing all your geocaching logs.

# %%
pQueryFile = '391079.gpx'
tree = ET.parse(pQueryFile)
root = tree.getroot()

# %% [markdown]
# ## XML Format
# The pocket query has this format:
# ```xml
# <gpx xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" version="1.0" creator="Groundspeak Pocket Query" xsi:schemaLocation="http://www.topografix.com/GPX/1/0 http://www.topografix.com/GPX/1/0/gpx.xsd http://www.groundspeak.com/cache/1/0/1 http://www.groundspeak.com/cache/1/0/1/cache.xsd" xmlns="http://www.topografix.com/GPX/1/0">
#   <name>My Finds Pocket Query</name>
#   <desc>Geocache file generated by Groundspeak</desc>
#   <author>Groundspeak</author>
#   <email>contact@groundspeak.com</email>
#   <time>2018-11-14T00:16:12.1350479Z</time>
#   <keywords>cache, geocache, groundspeak</keywords>
#   <bounds minlat="26.063217" minlon="-118.640633" maxlat="44.570867" maxlon="-70.8668" />
#   <wpt lat="33.745217" lon="-112.090783">
#       ... See below ....
#   </wpt>
# </gpx>
# ```
#
# There will be multiple `<wpt>` entries, each one with the following format:
# ```xml
#   <wpt lat="33.745217" lon="-112.090783">
#     <time>2010-05-26T07:00:00Z</time>
#     <name>GC2988Z</name>
#     <desc>Sonoran Trail # 3, "Lets sit here" by kira's rangers, Traditional Cache (2/3.5)</desc>
#     <url>http://www.geocaching.com/seek/cache_details.aspx?guid=237c350f-8f30-4885-82ab-923fcf6d4a91</url>
#     <urlname>Sonoran Trail # 3, "Lets sit here"</urlname>
#     <sym>Geocache Found</sym>
#     <type>Geocache|Traditional Cache</type>
#     <groundspeak:cache id="1712007" available="False" archived="True" xmlns:groundspeak="http://www.groundspeak.com/cache/1/0/1">
#       <groundspeak:name>Sonoran Trail # 3, "Lets sit here"</groundspeak:name>
#       <groundspeak:placed_by>kira's rangers</groundspeak:placed_by>
#       <groundspeak:owner id="2037845">kira's rangers</groundspeak:owner>
#       <groundspeak:type>Traditional Cache</groundspeak:type>
#       <groundspeak:container>Micro</groundspeak:container>
#       <groundspeak:attributes>
#         <groundspeak:attribute id="34" inc="0">Quads</groundspeak:attribute>
#         <groundspeak:attribute id="33" inc="0">Motorcycles</groundspeak:attribute>
#         <groundspeak:attribute id="35" inc="0">Off-road vehicles</groundspeak:attribute>
#         <groundspeak:attribute id="32" inc="1">Bicycles</groundspeak:attribute>
#         <groundspeak:attribute id="1" inc="1">Dogs</groundspeak:attribute>
#       </groundspeak:attributes>
#       <groundspeak:difficulty>2</groundspeak:difficulty>
#       <groundspeak:terrain>3.5</groundspeak:terrain>
#       <groundspeak:country>United States</groundspeak:country>
#       <groundspeak:state>Arizona</groundspeak:state>
#       <groundspeak:short_description html="False">short cache description</groundspeak:short_description>
#       <groundspeak:long_description html="False">L-O-N-G cache description</groundspeak:long_description>
#       <groundspeak:encoded_hints>
#       </groundspeak:encoded_hints>
#       <groundspeak:logs>
#         <groundspeak:log id="459354118">
#           <groundspeak:date>2014-11-04T20:00:00Z</groundspeak:date>
#           <groundspeak:type>Found it</groundspeak:type>
#           <groundspeak:finder id="30844">wsp2</groundspeak:finder>
#           <groundspeak:text encoded="False">Your log entry</groundspeak:text>
#         </groundspeak:log>
#       </groundspeak:logs>
#       <groundspeak:travelbugs />
#     </groundspeak:cache>
#   </wpt>
# ```

# %%
# Add the namespaces to make life easier
ns = {'gpx': 'http://www.topografix.com/GPX/1/0',
      'gc':  'http://www.groundspeak.com/cache/1/0/1',}

# %%
# Extract some of the header info
pqName = root.find('gpx:name', ns).text
pqDesc = root.find('gpx:desc', ns).text
pqTime = root.find('gpx:time', ns).text
pqBounds = root.find('gpx:bounds', ns).attrib

# Find the center of the map using the bounds of the query
mapCenter = [np.mean([float(pqBounds['minlat']), float(pqBounds['maxlat'])]), 
             np.mean([float(pqBounds['minlon']), float(pqBounds['maxlon'])])]

# %% [markdown]
# ## Create dataframe with pocket query waypoint data

# %%
#columns = ['GCName', 'Lat', 'Lon', 'Time', 'Type', 'Name', 'Container', 'Difficulty', 'Terrain', 'Country', 'State', 'LogType', 'LogDate']
#df = pd.DataFrame(columns=columns)

logList = []

# %%
entries = root.findall('gpx:wpt', ns)
for cache in root.findall('gpx:wpt', ns):
    for log in cache.findall('gc:cache/gc:logs/gc:log', ns):
        d = {}
        d['GCName']     = cache.find('gpx:name', ns).text
        d['Lat']        = float(cache.attrib['lat'])
        d['Lon']        = float(cache.attrib['lon'])
        d['Time']       = pd.Timestamp(cache.find('gpx:time', ns).text)
        d['Name']       = cache.find('gc:cache/gc:name', ns).text
        d['Container']  = cache.find('gc:cache/gc:container', ns).text
        d['Difficulty'] = float(cache.find('gc:cache/gc:difficulty', ns).text)
        d['Terrain']    = float(cache.find('gc:cache/gc:terrain', ns).text)
        d['Country']    = cache.find('gc:cache/gc:country', ns).text
        d['State']      = cache.find('gc:cache/gc:state', ns).text
        d['LogType']    = log.find('gc:type', ns).text
        d['LogDate']    = pd.Timestamp(log.find('gc:date', ns).text)
    logList.append(d)

# %%
df = pd.DataFrame(logList)

# %%
df
# Out:
#        Container        Country  Difficulty   GCName        Lat  \
# 0          Micro  United States         2.0  GC2988Z  33.745217
# 1          Micro  United States         2.0  GC6E670  33.702450
# 2          Micro  United States         2.0  GC6EAKY  33.714333
# 3          Micro  United States         2.0  GC6EAVN  33.716933
# 4          Micro  United States         2.0  GC6EDEF  33.718833
# 5          Micro  United States         1.5  GC3G9D4  35.364433
# 6          Small  United States         1.5  GC3R730  35.396233
# 7          Micro  United States         2.0  GC3R73H  35.395017
# 8          Other  United States         1.5  GC28YKP  34.004433
# 9        Regular  United States         2.0  GC2MRFA  38.947433
# 10         Micro  United States         1.5  GC4RN5W  39.537367
# 11       Regular  United States         2.0   GCGCH1  37.628283
# 12       Regular  United States         1.0  GC1TBTE  39.250783
# 13         Micro  United States         1.5  GC2RZK8  28.170967
# 14         Small  United States         1.5   GCXG6N  28.194100
# 15         Other  United States         1.5  GC69187  32.544883
# 16       Regular  United States         2.0  GC69C63  32.548917
# 17       Regular  United States         1.5  GC69H7G  32.540817
# 18         Micro  United States         1.5  GC60CAZ  42.279050
# 19         Micro  United States         1.5  GC3HZJA  42.391317
# 20         Small  United States         1.0  GC5A0JF  44.446233
# 21         Small  United States         1.5  GC220FC  43.500917
# 22         Large  United States         1.0  GC2THQN  37.646733
# 23       Virtual  United States         1.0   GC9D67  36.112533
# 24       Regular  United States         2.0   GC1BE3  40.848250
# 25       Regular  United States         2.0   GC1141  40.780683
# 26         Micro  United States         3.5   GCW0DX  32.384817
# 27         Small  United States         2.0  GC1F4T3  43.140950
# 28         Other  United States         2.5  GC7FD88  43.000900
# 29         Small  United States         1.5   GCK6AX  35.199867
# ...          ...            ...         ...      ...        ...
# 2540     Regular  United States         2.0   GCRT39  32.775500
# 2541     Regular  United States         2.0   GCTFJN  32.699167
# 2542     Regular  United States         3.0   GCTPW5  31.440133
# 2543       Micro  United States         1.5   GCVQM1  32.680883
# 2544       Micro  United States         1.5   GCWMYD  32.591033
# 2545       Small  United States         2.0  GC10N7Y  32.394167
# 2546       Small  United States         1.5  GC114AD  32.396800
# 2547  Not chosen  United States         1.5  GC11HGM  32.432217
# 2548     Regular  United States         1.5  GC11HNM  33.186283
# 2549       Small  United States         2.0  GC14B74  32.805600
# 2550       Small  United States         1.5  GC15E51  32.650700
# 2551     Virtual  United States         1.0   GC306A  30.660967
# 2552     Virtual  United States         1.0   GC9EAA  32.483700
# 2553     Virtual  United States         1.0   GCF495  30.322683
# 2554     Regular  United States         1.5   GCGXQ1  32.403967
# 2555       Micro  United States         2.0  GC3A4YA  32.928367
# 2556       Small  United States         1.5  GC3BCPM  32.627550
# 2557       Small  United States         2.0  GC160E7  32.611383
# 2558       Micro  United States         1.5  GC3HWB6  32.925717
# 2559       Micro  United States         2.0  GC3PR1C  32.925833
# 2560       Small  United States         1.0  GC3WFTJ  32.475250
# 2561       Small  United States         1.0  GC3WFZ6  32.482833
# 2562       Micro  United States         1.5  GC3Z79P  32.716367
# 2563       Micro  United States         1.5  GC44Y7E  32.467267
# 2564       Micro  United States         1.5  GC47125  32.788150
# 2565       Micro  United States         1.5  GC4MFJ2  32.603433
# 2566       Micro  United States         1.5  GC4NZ92  32.595883
# 2567       Other  United States         1.5  GC4Q9WM  32.615117
# 2568       Small  United States         2.0  GC63A1W  32.630867
# 2569       Micro  United States         1.5  GC2KD1D  43.802633
#
#                        LogDate   LogType         Lon  \
# 0    2014-11-04 20:00:00+00:00  Found it -112.090783
# 1    2018-10-25 19:00:00+00:00  Found it -111.955917
# 2    2018-10-25 19:00:00+00:00  Found it -111.958683
# 3    2018-10-25 19:00:00+00:00  Found it -111.950100
# 4    2018-10-25 19:00:00+00:00  Found it -111.959833
# 5    2014-07-20 19:00:00+00:00  Found it  -94.377050
# 6    2014-07-20 19:00:00+00:00  Found it  -94.368833
# 7    2014-07-20 19:00:00+00:00  Found it  -94.371217
# 8    2012-07-13 18:13:52+00:00  Found it -118.486950
# 9    2014-06-17 19:00:00+00:00  Found it -105.381400
# 10   2016-07-25 17:41:30+00:00  Found it -106.141850
# 11   2006-02-28 08:00:00+00:00  Found it -107.823917
# 12   2016-07-25 02:07:45+00:00  Found it -106.292967
# 13   2016-02-08 20:00:00+00:00  Found it  -81.827067
# 14   2013-09-24 17:07:44+00:00  Found it  -81.828617
# 15   2017-11-08 19:54:16+00:00  Found it  -82.124533
# 16   2017-11-08 19:02:35+00:00  Found it  -82.115133
# 17   2017-11-08 18:16:05+00:00  Found it  -82.115767
# 18   2016-10-18 02:23:37+00:00  Found it  -89.079633
# 19   2018-04-21 22:11:24+00:00  Found it  -88.752267
# 20   2015-12-11 20:00:00+00:00  Found it  -92.261717
# 21   2013-10-27 23:12:48+00:00  Found it  -91.284667
# 22   2014-03-28 19:00:00+00:00  Found it -115.745867
# 23   2005-02-12 08:00:00+00:00  Found it -115.172183
# 24   2002-06-11 07:00:00+00:00  Found it  -74.494367
# 25   2001-12-08 08:00:00+00:00  Found it  -74.540517
# 26   2007-03-14 07:00:00+00:00  Found it -106.550600
# 27   2016-06-12 19:00:00+00:00  Found it  -77.564967
# 28   2018-05-30 17:22:39+00:00  Found it  -77.460717
# 29   2017-11-05 18:59:27+00:00  Found it  -82.234783
# ...                        ...       ...         ...
# 2540 2007-07-22 07:00:00+00:00  Found it  -97.668233
# 2541 2006-10-07 07:00:00+00:00  Found it  -97.163100
# 2542 2016-01-18 20:00:00+00:00  Found it  -98.587583
# 2543 2013-09-10 01:22:59+00:00  Found it  -97.112767
# 2544 2007-08-19 07:00:00+00:00  Found it  -97.144133
# 2545 2009-10-25 19:00:00+00:00  Found it  -99.387467
# 2546 2010-07-05 19:00:00+00:00  Found it  -96.865750
# 2547 2007-09-02 07:00:00+00:00  Found it  -94.880667
# 2548 2012-09-08 19:00:00+00:00  Found it  -96.324533
# 2549 2013-09-07 20:18:52+00:00  Found it  -98.173800
# 2550 2009-01-04 20:00:00+00:00  Found it  -97.110083
# 2551 2016-06-27 17:56:31+00:00  Found it  -95.510867
# 2552 2010-07-05 19:00:00+00:00  Found it  -96.994383
# 2553 2006-11-19 08:00:00+00:00  Found it  -95.471717
# 2554 2004-10-09 07:00:00+00:00  Found it  -97.331117
# 2555 2015-10-04 19:00:00+00:00  Found it  -96.475617
# 2556 2014-01-05 20:00:00+00:00  Found it  -97.187783
# 2557 2010-10-10 19:00:00+00:00  Found it  -97.182667
# 2558 2015-10-04 19:00:00+00:00  Found it  -96.488283
# 2559 2015-10-04 19:00:00+00:00  Found it  -96.490833
# 2560 2014-01-12 20:00:00+00:00  Found it  -97.084033
# 2561 2014-01-12 20:00:00+00:00  Found it  -97.089283
# 2562 2013-03-24 19:00:00+00:00  Found it  -97.293033
# 2563 2014-01-12 20:00:00+00:00  Found it  -97.065717
# 2564 2013-09-07 15:25:23+00:00  Found it  -97.935533
# 2565 2014-11-29 20:00:00+00:00  Found it  -97.067700
# 2566 2014-02-23 20:00:00+00:00  Found it  -97.068100
# 2567 2014-01-24 20:00:00+00:00  Found it  -96.986950
# 2568 2016-01-03 20:00:00+00:00  Found it  -97.187650
# 2569 2013-10-27 16:37:15+00:00  Found it  -91.253500
#
#                                               Name           State  Terrain  \
# 0               Sonoran Trail # 3, "Lets sit here"         Arizona      3.5
# 1                               AZ Stickman "five"         Arizona      2.0
# 2                         AZ Stickman "twentyfour"         Arizona      2.0
# 3                         AZ Stickman "thirtyfour"         Arizona      2.0
# 4                              AZ Stickman "sixty"         Arizona      2.0
# 5                              ROCKS, ROCKS, ROCKS        Arkansas      2.0
# 6                                          The Ent        Arkansas      1.5
# 7                                          Weeping        Arkansas      1.5
# 8                         Community (Garden) Cache      California      1.0
# 9                                       Animal Den        Colorado      2.5
# 10                                        Snow Day        Colorado      1.5
# 11                            Purgatory View Cache        Colorado      2.0
# 12    Kassidy's Road House Lodge[Travel Buq Hotel]        Colorado      1.0
# 13               Project 365 #111 - TECO Trail #22         Florida      1.5
# 14                            Kaptn's Mate's Cache         Florida      1.5
# 15                      Emanuel County's Watershed         Georgia      1.5
# 16                          Barrel Full Of Monkeys         Georgia      2.0
# 17                                 Ace In The Hole         Georgia      2.0
# 18                                Little Log Cabin        Illinois      1.0
# 19                          SPPT #021 - No Shelter        Illinois      1.5
# 20                                  Horseshoe Park       Minnesota      1.0
# 21                               cornered MN style       Minnesota      1.5
# 22                                         QUARK'S          Nevada      1.0
# 23                                    Eiffel Tower          Nevada      1.0
# 24    Limpidity-4: George Washington's StairMaster      New Jersey      2.5
# 25        Sierra Bravo-03-Lewis Morris County Park      New Jersey      2.0
# 26                           On the Way to Aguirre      New Mexico      2.0
# 27                               Lunch Box Returns        New York      3.0
# 28                 Lehigh Valley Trail Stroll # 23        New York      1.5
# 29                                Welcome To Tryon  North Carolina      1.5
# ...                                            ...             ...      ...
# 2540                                FOSSIL = BLUFF           Texas      3.0
# 2541                                     Calypso 1           Texas      1.5
# 2542                                 REST IN PEACE           Texas      1.5
# 2543                Where did this mall come from?           Texas      1.5
# 2544                                      Bullseye           Texas      1.5
# 2545                                 Loose Caboose           Texas      1.5
# 2546                Is there a Doctor In the House           Texas      1.0
# 2547                                    Litter Bug           Texas      1.5
# 2548                             Rick's 10 fingers           Texas      2.0
# 2549                         HPHR Indian Creek Too           Texas      1.5
# 2550                                  Wasabi Dude?           Texas      1.5
# 2551                            Tribute to Courage           Texas      1.0
# 2552                       The Half Dovetail Notch           Texas      1.0
# 2553  I Love the Smell of Napalm in the Morning!!!           Texas      1.0
# 2554                                  Office Depot           Texas      1.5
# 2555                           Bridge of Icons #01           Texas      1.5
# 2556                            Tierra Verde Multi           Texas      1.5
# 2557    Dying To Get in - Cedar Hill Memorial - #3           Texas      1.0
# 2558                           Bridge of Icons #06           Texas      1.5
# 2559                           Bridge of Icons #07           Texas      1.5
# 2560                 Brucie - The Fairyland Series           Texas      1.5
# 2561                Faylinn - The Fairyland Series           Texas      1.5
# 2562                                  On the Rocks           Texas      1.5
# 2563                  Fair Song - Fairyland Series           Texas      1.5
# 2564                             Caching Rest Stop           Texas      1.5
# 2565                        Loyd Park Bike Trail 8           Texas      1.5
# 2566                                    Crossroads           Texas      1.5
# 2567                                      Rat Fink           Texas      1.5
# 2568                       Birdhouse Letterbox # 2           Texas      1.5
# 2569                            that a lot of beer       Wisconsin      1.5
#
#                           Time
# 0    2010-05-26 07:00:00+00:00
# 1    2016-03-15 07:00:00+00:00
# 2    2016-03-15 07:00:00+00:00
# 3    2016-03-15 07:00:00+00:00
# 4    2016-03-15 07:00:00+00:00
# 5    2012-04-05 07:00:00+00:00
# 6    2012-07-24 07:00:00+00:00
# 7    2012-07-24 07:00:00+00:00
# 8    2010-06-02 07:00:00+00:00
# 9    2011-01-22 08:00:00+00:00
# 10   2013-11-06 08:00:00+00:00
# 11   2003-06-29 07:00:00+00:00
# 12   2009-06-06 07:00:00+00:00
# 13   2011-04-21 07:00:00+00:00
# 14   2006-08-03 07:00:00+00:00
# 15   2016-01-01 08:00:00+00:00
# 16   2016-01-07 08:00:00+00:00
# 17   2016-01-11 08:00:00+00:00
# 18   2015-07-28 07:00:00+00:00
# 19   2012-04-25 07:00:00+00:00
# 20   2014-07-31 07:00:00+00:00
# 21   2009-12-14 08:00:00+00:00
# 22   2011-04-19 07:00:00+00:00
# 23   2002-10-12 07:00:00+00:00
# 24   2001-09-08 07:00:00+00:00
# 25   2001-07-17 07:00:00+00:00
# 26   2006-05-12 07:00:00+00:00
# 27   2008-08-11 07:00:00+00:00
# 28   2017-11-27 08:00:00+00:00
# 29   2004-08-07 07:00:00+00:00
# ...                        ...
# 2540 2005-12-30 08:00:00+00:00
# 2541 2006-02-15 08:00:00+00:00
# 2542 2006-03-04 08:00:00+00:00
# 2543 2006-05-02 07:00:00+00:00
# 2544 2006-06-17 07:00:00+00:00
# 2545 2007-01-28 08:00:00+00:00
# 2546 2007-02-24 08:00:00+00:00
# 2547 2007-03-18 07:00:00+00:00
# 2548 2007-03-18 07:00:00+00:00
# 2549 2007-07-13 07:00:00+00:00
# 2550 2007-08-26 07:00:00+00:00
# 2551 2002-01-02 08:00:00+00:00
# 2552 2002-10-20 07:00:00+00:00
# 2553 2003-04-06 08:00:00+00:00
# 2554 2003-09-18 07:00:00+00:00
# 2555 2012-07-20 07:00:00+00:00
# 2556 2012-01-25 08:00:00+00:00
# 2557 2007-09-16 07:00:00+00:00
# 2558 2012-07-20 07:00:00+00:00
# 2559 2012-07-20 07:00:00+00:00
# 2560 2012-09-09 07:00:00+00:00
# 2561 2012-09-09 07:00:00+00:00
# 2562 2012-10-22 07:00:00+00:00
# 2563 2013-01-25 08:00:00+00:00
# 2564 2013-03-03 08:00:00+00:00
# 2565 2013-09-02 07:00:00+00:00
# 2566 2013-09-24 07:00:00+00:00
# 2567 2013-10-15 07:00:00+00:00
# 2568 2015-09-11 07:00:00+00:00
# 2569 2010-12-16 08:00:00+00:00
#
# [2570 rows x 12 columns]

# %% [markdown]
# ## Begin building the map

# %%
cacheMap = folium.Map(location=mapCenter, zoom_start=2)
# fit_bounds takes list of two coords: southwest and northeast
cacheMap.fit_bounds([[float(pqBounds['minlat']), float(pqBounds['minlon'])], 
                     [float(pqBounds['maxlat']), float(pqBounds['maxlon'])]])

#cacheMap

# %% [markdown]
# ## Add geocaches to the map

# %%
# instantiate a feature group for the geocaches
caches = folium.map.FeatureGroup()

for cache in root.findall('gpx:wpt', ns):
    caches.add_child(
        folium.CircleMarker(
            [float(cache.attrib['lat']), float(cache.attrib['lon'])],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6))
# add pop-up text to each marker on the map
#latitudes = list(df_incidents.Y)
#longitudes = list(df_incidents.X)
#labels = list(df_incidents.Category)

#for lat, lng, label in zip(latitudes, longitudes, labels):
#    folium.Marker([lat, lng], popup=label).add_to(sanfran_map)    
    
# add incidents to map
cacheMap.add_child(caches)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
